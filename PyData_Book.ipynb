# %%
import numpy as np
import pandas as pd
# %matplotlib nbagg
import matplotlib.pyplot as plt

# %%
path = 'ch02/usagov_bitly_data2012-03-16-1331923249.txt'

# %%
open(path).readline()
# Out:
# '{ "a": "Mozilla\\/5.0 (Windows NT 6.1; WOW64) AppleWebKit\\/535.11 (KHTML, like Gecko) Chrome\\/17.0.963.78 Safari\\/535.11", "c": "US", "nk": 1, "tz": "America\\/New_York", "gr": "MA", "g": "A6qOVH", "h": "wfLQtf", "l": "orofrog", "al": "en-US,en;q=0.8", "hh": "1.usa.gov", "r": "http:\\/\\/www.facebook.com\\/l\\/7AQEFzjSi\\/1.usa.gov\\/wfLQtf", "u": "http:\\/\\/www.ncbi.nlm.nih.gov\\/pubmed\\/22415991", "t": 1331923247, "hc": 1331822918, "cy": "Danvers", "ll": [ 42.576698, -70.954903 ] }\n'

# %%
import json

# %%
records = [json.loads(line) for line in open(path, 'rb')]

# %%
records[0:2]
# Out:
# [{u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#   u'al': u'en-US,en;q=0.8',
#   u'c': u'US',
#   u'cy': u'Danvers',
#   u'g': u'A6qOVH',
#   u'gr': u'MA',
#   u'h': u'wfLQtf',
#   u'hc': 1331822918,
#   u'hh': u'1.usa.gov',
#   u'l': u'orofrog',
#   u'll': [42.576698, -70.954903],
#   u'nk': 1,
#   u'r': u'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#   u't': 1331923247,
#   u'tz': u'America/New_York',
#   u'u': u'http://www.ncbi.nlm.nih.gov/pubmed/22415991'},
#  {u'a': u'GoogleMaps/RochesterNY',
#   u'c': u'US',
#   u'cy': u'Provo',
#   u'g': u'mwszkS',
#   u'gr': u'UT',
#   u'h': u'mwszkS',
#   u'hc': 1308262393,
#   u'hh': u'j.mp',
#   u'l': u'bitly',
#   u'll': [40.218102, -111.613297],
#   u'nk': 0,
#   u'r': u'http://www.AwareMap.com/',
#   u't': 1331923249,
#   u'tz': u'America/Denver',
#   u'u': u'http://www.monroecounty.gov/etc/911/rss.php'}]

# %%
records[0]
# Out:
# {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#  u'al': u'en-US,en;q=0.8',
#  u'c': u'US',
#  u'cy': u'Danvers',
#  u'g': u'A6qOVH',
#  u'gr': u'MA',
#  u'h': u'wfLQtf',
#  u'hc': 1331822918,
#  u'hh': u'1.usa.gov',
#  u'l': u'orofrog',
#  u'll': [42.576698, -70.954903],
#  u'nk': 1,
#  u'r': u'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#  u't': 1331923247,
#  u'tz': u'America/New_York',
#  u'u': u'http://www.ncbi.nlm.nih.gov/pubmed/22415991'}

# %%
records[0]['tz']
# Out:
# u'America/New_York'

# %% [markdown]
# #### u stands for unicode: an international encoding standard for use with different languages and scripts, by which each letter, digit, or symbol is assigned a unique numeric value that applies across different platforms and programs.

# %%
print records[0]['tz']
# Out:
# America/New_York

# %%
time_zones = [rec['tz'] for rec in records if 'tz' in rec]

# %%
time_zones[:10]
# Out:
# [u'America/New_York',
#  u'America/Denver',
#  u'America/New_York',
#  u'America/Sao_Paulo',
#  u'America/New_York',
#  u'America/New_York',
#  u'Europe/Warsaw',
#  u'',
#  u'',
#  u'']

# %%
def get_counts(sequence):
    counts = {}
    for x in sequence:
        if x in counts:
            counts[x] += 1
        else:
            counts[x] = 1
    return counts

# %%
from collections import defaultdict

# %%
def get_counts2(sequence):
    counts = defaultdict(int)
    for x in sequence:
        counts[x] +=1
    return counts

# %%
"""defaultdict()

Docstring:
defaultdict(default_factory[, ...]) --> dict with default factory

The default factory is called without arguments to produce
a new value when a key is not present, in __getitem__ only.
A defaultdict compares equal to a dict with the same items.
All remaining arguments are treated the same as if they were
passed to the dict constructor, including keyword arguments."""
# Out:
# 'defaultdict()\n\nDocstring:\ndefaultdict(default_factory[, ...]) --> dict with default factory\n\nThe default factory is called without arguments to produce\na new value when a key is not present, in __getitem__ only.\nA defaultdict compares equal to a dict with the same items.\nAll remaining arguments are treated the same as if they were\npassed to the dict constructor, including keyword arguments.'

# %%
counts = get_counts(time_zones)

# %%
counts['America/New_York']
# Out:
# 1251

# %%
count = 0
for key, value in counts.items():
    print key, value
    count += 1
    if count > 5:
        break
# Out:
#  521
# Europe/Lisbon 8
# Asia/Calcutta 9
# Europe/Skopje 1
# Europe/Copenhagen 5
# Europe/Amsterdam 22

# %%
type(counts)
# Out:
# dict

# %%
len(time_zones)
# Out:
# 3440

# %%
def top_counts(count_dict, n=10):
    value_key_pairs = [(count, tz) for tz, count in count_dict.items()]
    value_key_pairs.sort()
    return value_key_pairs[-n:]

# %%
top_counts(counts)
# Out:
# [(33, u'America/Sao_Paulo'),
#  (35, u'Europe/Madrid'),
#  (36, u'Pacific/Honolulu'),
#  (37, u'Asia/Tokyo'),
#  (74, u'Europe/London'),
#  (191, u'America/Denver'),
#  (382, u'America/Los_Angeles'),
#  (400, u'America/Chicago'),
#  (521, u''),
#  (1251, u'America/New_York')]

# %%
from collections import Counter

# %%
from pandas import DataFrame, Series

# %%
import pandas as pd

# %%
frame = DataFrame(records)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3560 entries, 0 to 3559
# Data columns (total 18 columns):
# _heartbeat_    120 non-null float64
# a              3440 non-null object
# al             3094 non-null object
# c              2919 non-null object
# cy             2919 non-null object
# g              3440 non-null object
# gr             2919 non-null object
# h              3440 non-null object
# hc             3440 non-null float64
# hh             3440 non-null object
# kw             93 non-null object
# l              3440 non-null object
# ll             2919 non-null object
# nk             3440 non-null float64
# r              3440 non-null object
# t              3440 non-null float64
# tz             3440 non-null object
# u              3440 non-null object
# dtypes: float64(4), object(14)
# memory usage: 528.4+ KB

# %%
tz_counts = frame['tz'].value_counts()

# %%
frame.head()
# Out:
#    _heartbeat_                                                  a  \
# 0          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1          NaN                             GoogleMaps/RochesterNY
# 2          NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#                al   c          cy       g  gr       h          hc         hh  \
# 0  en-US,en;q=0.8  US     Danvers  A6qOVH  MA  wfLQtf  1331822918  1.usa.gov
# 1             NaN  US       Provo  mwszkS  UT  mwszkS  1308262393       j.mp
# 2           en-US  US  Washington  xxr3Qb  DC  xxr3Qb  1331919941  1.usa.gov
# 3           pt-br  BR        Braz  zCaLwp  27  zUtuOu  1331923068  1.usa.gov
# 4  en-US,en;q=0.8  US  Shrewsbury  9b6kNl  MA  9b6kNl  1273672411     bit.ly
#
#     kw         l                        ll  nk  \
# 0  NaN   orofrog   [42.576698, -70.954903]   1
# 1  NaN     bitly  [40.218102, -111.613297]   0
# 2  NaN     bitly     [38.9007, -77.043098]   1
# 3  NaN  alelex88  [-23.549999, -46.616699]   0
# 4  NaN     bitly   [42.286499, -71.714699]   0
#
#                                                    r           t  \
# 0  http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...  1331923247
# 1                           http://www.AwareMap.com/  1331923249
# 2                               http://t.co/03elZC4Q  1331923250
# 3                                             direct  1331923249
# 4                http://www.shrewsbury-ma.gov/selco/  1331923251
#
#                   tz                                                  u
# 0   America/New_York        http://www.ncbi.nlm.nih.gov/pubmed/22415991
# 1     America/Denver        http://www.monroecounty.gov/etc/911/rss.php
# 2   America/New_York  http://boxer.senate.gov/en/press/releases/0316...
# 3  America/Sao_Paulo            http://apod.nasa.gov/apod/ap120312.html
# 4   America/New_York  http://www.shrewsbury-ma.gov/egov/gallery/1341...

# %%
tz_counts[:10]
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# dtype: int64

# %%
## what is the equivalent of the above using a different index format?
tz_counts[:(10 - len(tz_counts))]
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# dtype: int64

# %%
clean_tz = frame['tz'].fillna('Missing')

# %%
clean_tz[clean_tz == ''] = 'Unknown'

# %%
tz_counts = clean_tz.value_counts()

# %%
tz_counts[:10]
# Out:
# America/New_York       1251
# Unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# dtype: int64

# %%
tz_counts[:10].plot(kind = 'barh', rot=0)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.show()

# %%
frame['a'][1]
# Out:
# u'GoogleMaps/RochesterNY'

# %%
frame['a'][50]
# Out:
# u'Mozilla/5.0 (Windows NT 5.1; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'

# %%
##frame['a']['51']

# %%
results = Series([x.split()[0] for x in frame.a.dropna()])

# %%
frame.head()
# Out:
#    _heartbeat_                                                  a  \
# 0          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1          NaN                             GoogleMaps/RochesterNY
# 2          NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#                al   c          cy       g  gr       h          hc         hh  \
# 0  en-US,en;q=0.8  US     Danvers  A6qOVH  MA  wfLQtf  1331822918  1.usa.gov
# 1             NaN  US       Provo  mwszkS  UT  mwszkS  1308262393       j.mp
# 2           en-US  US  Washington  xxr3Qb  DC  xxr3Qb  1331919941  1.usa.gov
# 3           pt-br  BR        Braz  zCaLwp  27  zUtuOu  1331923068  1.usa.gov
# 4  en-US,en;q=0.8  US  Shrewsbury  9b6kNl  MA  9b6kNl  1273672411     bit.ly
#
#     kw         l                        ll  nk  \
# 0  NaN   orofrog   [42.576698, -70.954903]   1
# 1  NaN     bitly  [40.218102, -111.613297]   0
# 2  NaN     bitly     [38.9007, -77.043098]   1
# 3  NaN  alelex88  [-23.549999, -46.616699]   0
# 4  NaN     bitly   [42.286499, -71.714699]   0
#
#                                                    r           t  \
# 0  http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...  1331923247
# 1                           http://www.AwareMap.com/  1331923249
# 2                               http://t.co/03elZC4Q  1331923250
# 3                                             direct  1331923249
# 4                http://www.shrewsbury-ma.gov/selco/  1331923251
#
#                   tz                                                  u
# 0   America/New_York        http://www.ncbi.nlm.nih.gov/pubmed/22415991
# 1     America/Denver        http://www.monroecounty.gov/etc/911/rss.php
# 2   America/New_York  http://boxer.senate.gov/en/press/releases/0316...
# 3  America/Sao_Paulo            http://apod.nasa.gov/apod/ap120312.html
# 4   America/New_York  http://www.shrewsbury-ma.gov/egov/gallery/1341...

# %%
frame.a.head()
# Out:
# 0    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1                               GoogleMaps/RochesterNY
# 2    Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4    Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# Name: a, dtype: object

# %%
results[:5]
# Out:
# 0               Mozilla/5.0
# 1    GoogleMaps/RochesterNY
# 2               Mozilla/4.0
# 3               Mozilla/5.0
# 4               Mozilla/5.0
# dtype: object

# %%
results.value_counts()[:8]
# Out:
# Mozilla/5.0                 2594
# Mozilla/4.0                  601
# GoogleMaps/RochesterNY       121
# Opera/9.80                    34
# TEST_INTERNET_AGENT           24
# GoogleProducer                21
# Mozilla/6.0                    5
# BlackBerry8520/5.0.0.681       4
# dtype: int64

# %% [markdown]
# ###.value_counts(): Returns object containing counts of unique values.The resulting object will be in descending order so that the first element is the most frequently-occurring element.

# %%
cframe = frame[frame.a.notnull()]

# %%
cframe.head()
# Out:
#    _heartbeat_                                                  a  \
# 0          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1          NaN                             GoogleMaps/RochesterNY
# 2          NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#                al   c          cy       g  gr       h          hc         hh  \
# 0  en-US,en;q=0.8  US     Danvers  A6qOVH  MA  wfLQtf  1331822918  1.usa.gov
# 1             NaN  US       Provo  mwszkS  UT  mwszkS  1308262393       j.mp
# 2           en-US  US  Washington  xxr3Qb  DC  xxr3Qb  1331919941  1.usa.gov
# 3           pt-br  BR        Braz  zCaLwp  27  zUtuOu  1331923068  1.usa.gov
# 4  en-US,en;q=0.8  US  Shrewsbury  9b6kNl  MA  9b6kNl  1273672411     bit.ly
#
#     kw         l                        ll  nk  \
# 0  NaN   orofrog   [42.576698, -70.954903]   1
# 1  NaN     bitly  [40.218102, -111.613297]   0
# 2  NaN     bitly     [38.9007, -77.043098]   1
# 3  NaN  alelex88  [-23.549999, -46.616699]   0
# 4  NaN     bitly   [42.286499, -71.714699]   0
#
#                                                    r           t  \
# 0  http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/...  1331923247
# 1                           http://www.AwareMap.com/  1331923249
# 2                               http://t.co/03elZC4Q  1331923250
# 3                                             direct  1331923249
# 4                http://www.shrewsbury-ma.gov/selco/  1331923251
#
#                   tz                                                  u
# 0   America/New_York        http://www.ncbi.nlm.nih.gov/pubmed/22415991
# 1     America/Denver        http://www.monroecounty.gov/etc/911/rss.php
# 2   America/New_York  http://boxer.senate.gov/en/press/releases/0316...
# 3  America/Sao_Paulo            http://apod.nasa.gov/apod/ap120312.html
# 4   America/New_York  http://www.shrewsbury-ma.gov/egov/gallery/1341...

# %%
operating_system = np.where(cframe['a'].str.contains('Windows'),'Windows', 'Not Windows')

# %%
type(operating_system)
# Out:
# numpy.ndarray

# %%
operating_system[:5]
# Out:
# array(['Windows', 'Not Windows', 'Windows', 'Not Windows', 'Windows'],
#       dtype='|S11')

# %%
by_tz_os = cframe.groupby(['tz', operating_system])

# %%
by_tz_os.head()
# Out:
#       _heartbeat_                                                  a  \
# 0             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1             NaN                             GoogleMaps/RochesterNY
# 2             NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3             NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 5             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6             NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 7             NaN  Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/2...
# 8             NaN  Opera/9.80 (X11; Linux zbov; U; en) Presto/2.1...
# 9             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 10            NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 11            NaN  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4...
# 12            NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 15            NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1...
# 16            NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1...
# 17            NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.5; r...
# 18            NaN                             GoogleMaps/RochesterNY
# 19            NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 20            NaN  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 21            NaN  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.6...
# 23            NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3)...
# 24            NaN  Mozilla/5.0 (Windows; U; Windows NT 5.1; es-ES...
# 25            NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1...
# 26            NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.1...
# 27            NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 28            NaN  Mozilla/5.0 (iPad; CPU OS 5_0_1 like Mac OS X)...
# 29            NaN  Mozilla/5.0 (iPad; U; CPU OS 3_2 like Mac OS X...
# 30            NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 32            NaN  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
# 33            NaN  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4...
# ...           ...                                                ...
# 3110          NaN  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3117          NaN  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_4_1...
# 3119          NaN  Mozilla/5.0 (iPad; U; CPU OS 4_3_3 like Mac OS...
# 3122          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_2)...
# 3130          NaN  Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US...
# 3140          NaN  Mozilla/5.0 (iPad; U; CPU OS 4_2_1 like Mac OS...
# 3154          NaN  Mozilla/5.0 (iPad; U; CPU iPhone OS 5_0_1 like...
# 3173          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 3175          NaN  Mozilla/5.0 (iPad; U; CPU iPhone OS 5_0_1 like...
# 3188          NaN  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT ...
# 3198          NaN  Mozilla/5.0 (Linux; U; Android 4.0.1; en-au; G...
# 3207          NaN  Mozilla/5.0 (Linux; U; Android 2.3.4; sv-se; S...
# 3208          NaN  Mozilla/5.0 (Linux; U; Android 2.3.4; sv-se; S...
# 3248          NaN  Mozilla/5.0 (iPhone; U; CPU iPhone OS 4_2_1 li...
# 3279          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3)...
# 3347          NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 3353          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3)...
# 3357          NaN  Mozilla/5.0 (Linux; U; Android 2.3.3; en-us; D...
# 3358          NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 3361          NaN  Mozilla/5.0 (BlackBerry; U; BlackBerry 9700; e...
# 3362          NaN  Dalvik/1.4.0 (Linux; U; Android 2.3.3; DROIDX ...
# 3404          NaN     Opera/9.64(Windows NT 5.1; U; en) Presto/2.1.1
# 3420          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 3428          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_8)...
# 3445          NaN  Mozilla/5.0 (iPad; CPU OS 5_1 like Mac OS X) A...
# 3455          NaN  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.7...
# 3496          NaN  Mozilla/5.0 (iPhone; CPU iPhone OS 5_0_1 like ...
# 3506          NaN  Mozilla/5.0 (iPhone; CPU iPhone OS 5_0_1 like ...
# 3514          NaN  Mozilla/5.0 (iPad; CPU OS 5_0_1 like Mac OS X)...
# 3537          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
#
#                                           al     c                cy       g  \
# 0                             en-US,en;q=0.8    US           Danvers  A6qOVH
# 1                                        NaN    US             Provo  mwszkS
# 2                                      en-US    US        Washington  xxr3Qb
# 3                                      pt-br    BR              Braz  zCaLwp
# 4                             en-US,en;q=0.8    US        Shrewsbury  9b6kNl
# 5                             en-US,en;q=0.8    US        Shrewsbury  axNK8c
# 6        pl-PL,pl;q=0.8,en-US;q=0.6,en;q=0.4    PL             Luban  wcndER
# 7                    bg,en-us;q=0.7,en;q=0.3  None               NaN  wcndER
# 8                                  en-US, en  None               NaN  wcndER
# 9        pt-BR,pt;q=0.8,en-US;q=0.6,en;q=0.4  None               NaN  zCaLwp
# 10                            en-us,en;q=0.5    US           Seattle  vNJS4H
# 11                            en-us,en;q=0.5    US        Washington  wG7OIH
# 12                            en-us,en;q=0.5    US        Alexandria  vNJS4H
# 15       zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4    HK  Central District  nQvgJp
# 16       zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4    HK  Central District   XdUNr
# 17                            en-us,en;q=0.5    US         Buckfield  zH1BFf
# 18                                       NaN    US             Provo  mwszkS
# 19       it-IT,it;q=0.8,en-US;q=0.6,en;q=0.4    IT            Venice  wcndER
# 20                                     es-ES    ES             Alcal  zQ95Hi
# 21                            en-us,en;q=0.5    US     Davidsonville  wcndER
# 23                                     en-us    US            Lititz  wWiOiD
# 24       es-es,es;q=0.8,en-us;q=0.5,en;q=0.3    ES            Bilbao  wcndER
# 25    en-GB,en;q=0.8,en-US;q=0.6,en-AU;q=0.4    MY      Kuala Lumpur  wcndER
# 26       ro-RO,ro;q=0.8,en-US;q=0.6,en;q=0.4    CY           Nicosia  wcndER
# 27                            en-US,en;q=0.8    BR            SPaulo  zCaLwp
# 28                                     en-us  None               NaN  vNJS4H
# 29                                     en-us  None               NaN  FPX0IM
# 30                en-GB,en-US;q=0.8,en;q=0.6    GB      Huddersfield  wcndER
# 32                                     en-us    US          Honolulu  FO8qn8
# 33                            en-us,en;q=0.5    US         Knoxville  y5uuLa
# ...                                      ...   ...               ...     ...
# 3110                                   en-US    BO        Santa Cruz  nMIFDR
# 3117                                      ru    RU  Saint Petersburg  y4NeMN
# 3119                                   es-es    MX        Nezahualcl  zCaLwp
# 3122                                   de-de    AT         Innsbruck  xVTtSE
# 3130     fr-FR,fr;q=0.8,en-US;q=0.6,en;q=0.4    MA             Rabat  wVUNKT
# 3140                                   en-us    AE             Dubai  w4Kn87
# 3154                                   ko-kr    KR             Seoul  wcndER
# 3173     fi-FI,fi;q=0.8,en-US;q=0.6,en;q=0.4    FI             Espoo  xVZg4P
# 3175                                   ko-kr    KR             Seoul  wcndER
# 3188     da-DK,da;q=0.8,en-US;q=0.6,en;q=0.4    DK          Ballerup  dQAcd9
# 3198                            en-AU, en-US    AU      Hunters Hill  xVZg4P
# 3207                            sv-SE, en-US    SE             Dalby  p7JcmT
# 3208                            sv-SE, en-US    SE             Dalby  p7JcmT
# 3248                                   cs-cz    CZ           Teplice  z1ztLK
# 3279                          en-US,en;q=0.8    AU      Quakers Hill  zJJv7V
# 3347     hu-HU,hu;q=0.8,en-US;q=0.6,en;q=0.4    HU          Budapest  wcndER
# 3353                                   nb-no    NO            Bergen  zkZ8eP
# 3357                                   en-US    ID           Jakarta  xVZg4P
# 3358     en-US,en;q=0.8,fr-CA;q=0.6,fr;q=0.4    CA           Calgary  wqGppe
# 3361                          en-US,en;q=0.5    US        Scottsdale  yR36fW
# 3362                                     NaN    ID           Jakarta  xVZg4P
# 3404                                     NaN    ID          Karawaci  cQyDKo
# 3420                          es-ES,es;q=0.8    IL    Rishon Le Zion  FO8od2
# 3428                                   fr-fr    FR             Sstat  xzIBR5
# 3445                                   en-us    US         Anchorage  y5rMac
# 3455                          en-US,en;q=0.8    PK            Multan  x3xKr9
# 3496                                   en-us    KR             Seoul  wQacbF
# 3506                                   en-us    KR             Seoul  wQacbF
# 3514                                   en-us    AE             Dubai  dpnS2f
# 3537     es-es,es;q=0.8,en-us;q=0.5,en;q=0.3    HN       Tegucigalpa  zCaLwp
#
#        gr       h          hc           hh          kw                l  \
# 0      MA  wfLQtf  1331822918    1.usa.gov         NaN          orofrog
# 1      UT  mwszkS  1308262393         j.mp         NaN            bitly
# 2      DC  xxr3Qb  1331919941    1.usa.gov         NaN            bitly
# 3      27  zUtuOu  1331923068    1.usa.gov         NaN         alelex88
# 4      MA  9b6kNl  1273672411       bit.ly         NaN            bitly
# 5      MA  axNK8c  1273672506       bit.ly         NaN            bitly
# 6      77  zkpJBR  1331922854    1.usa.gov         NaN         bnjacobs
#
# 3198        Australia/NSW  http://www.nasa.gov/multimedia/imagegallery/im...
# 3207     Europe/Stockholm  http://www.cpc.ncep.noaa.gov/products/fews/afr...
# 3208     Europe/Stockholm  http://www.cpc.ncep.noaa.gov/products/fews/afr...
# 3248        Europe/Prague  http://www.nasa.gov/mission_pages/icebridge/ne...
# 3279        Australia/NSW        http://www.ncbi.nlm.nih.gov/pubmed/22341379
# 3347      Europe/Budapest  http://www.nasa.gov/mission_pages/nustar/main/...
# 3353          Europe/Oslo  http://www.bnl.gov/bnlweb/pubaf/pr/PR_display....
# 3357         Asia/Jakarta  http://www.nasa.gov/multimedia/imagegallery/im...
# 3358     America/Edmonton  http://www.nasa.gov/mission_pages/sunearth/mis...
# 3361      America/Phoenix  http://blog.usa.gov/post/19240063355/winter-co...
# 3362         Asia/Jakarta  http://www.nasa.gov/multimedia/imagegallery/im...
# 3404         Asia/Jakarta      http://www.leesburgva.gov/index.aspx?page=566
# 3420       Asia/Jerusalem  http://www.nature.nps.gov/features/eclipse/whe...
# 3428         Europe/Paris  http://ntrs.nasa.gov/search.jsp?R=20120002810&...
# 3445    America/Anchorage    http://www.fda.gov/Safety/Recalls/ucm296326.htm
# 3455         Asia/Karachi        http://www.ncbi.nlm.nih.gov/pubmed/20059656
# 3496           Asia/Seoul  http://www.whitehouse.gov/energy/gasprices#.T2...
# 3506           Asia/Seoul  http://www.whitehouse.gov/energy/gasprices#.T2...
# 3514           Asia/Dubai  http://www.nhtsa.gov/Driving+Safety/Child+Safe...
# 3537  America/Tegucigalpa            http://apod.nasa.gov/apod/ap120312.html
#
# [429 rows x 18 columns]

# %%
by_tz_os.size().head()
# Out:
# tz
#                    Not Windows    245
#                    Windows        276
# Africa/Cairo       Windows          3
# Africa/Casablanca  Windows          1
# Africa/Ceuta       Windows          2
# dtype: int64

# %% [markdown]
# ##size(): used to find group counts, it's analogous to using value_counts()
# ##unstack(): reshapes the result into a table

# %%
agg_counts = by_tz_os.size().unstack().fillna(0)

# %%
agg_counts[:20]
# Out:
#                                 Not Windows  Windows
# tz
#                                         245      276
# Africa/Cairo                              0        3
# Africa/Casablanca                         0        1
# Africa/Ceuta                              0        2
# Africa/Johannesburg                       0        1
# Africa/Lusaka                             0        1
# America/Anchorage                         4        1
# America/Argentina/Buenos_Aires            1        0
# America/Argentina/Cordoba                 0        1
# America/Argentina/Mendoza                 0        1
# America/Bogota                            1        2
# America/Caracas                           0        1
# America/Chicago                         115      285
# America/Chihuahua                         1        1
# America/Costa_Rica                        0        1
# America/Denver                          132       59
# America/Edmonton                          2        4
# America/Guayaquil                         2        0
# America/Halifax                           1        3
# America/Indianapolis                      8       12

# %% [markdown]
# ##argsort(): constructs an indirect index array from the row counts in agg_counts

# %%
indexer = agg_counts.sum(1).argsort()

# %% [markdown]
# ##sum(): Return the sum of a sequence of numbers (NOT strings) plus the value

# %% [markdown]
# ### get the first 10

# %%
indexer[:10]
# Out:
# tz
#                                   24
# Africa/Cairo                      20
# Africa/Casablanca                 21
# Africa/Ceuta                      92
# Africa/Johannesburg               87
# Africa/Lusaka                     53
# America/Anchorage                 54
# America/Argentina/Buenos_Aires    57
# America/Argentina/Cordoba         26
# America/Argentina/Mendoza         55
# dtype: int64

# %%
count_subset = agg_counts.take(indexer)[-10:]

# %% [markdown]
# ##take: select the rows in that order, then slide off the last 10 rows

# %%
count_subset
# Out:
#                      Not Windows  Windows
# tz
# America/Sao_Paulo             13       20
# Europe/Madrid                 16       19
# Pacific/Honolulu               0       36
# Asia/Tokyo                     2       35
# Europe/London                 43       31
# America/Denver               132       59
# America/Los_Angeles          130      252
# America/Chicago              115      285
#                              245      276
# America/New_York             339      912

# %%
count_subset.plot(kind='barh', stacked=True)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.show()

# %%
normed_subset = count_subset.div(count_subset.sum(1), axis=0)

# %%
normed_subset.plot(kind='barh', stacked=True)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.show()

# %%
import pandas as pd

# %%
unames = ['user_id', 'gender', 'age', 'occupation', 'zip']

# %%
users = pd.read_table('ch02/movielens/users.dat', sep = '::', header=None, names=unames)
# Out:
# C:\Users\bhudnall\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\io\parsers.py:648: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %%
users.head()
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
rnames = ['user_id', 'movie_id', 'rating', 'timestamp']

# %%
rnames
# Out:
# ['user_id', 'movie_id', 'rating', 'timestamp']

# %%
ratings = pd.read_table('ch02/movielens/ratings.dat', sep='::', header=None, names=rnames)

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
mnames = ['movie_id', 'title', 'genres']

# %%
movies = pd.read_table('ch02/movielens/movies.dat', sep='::', header=None, names=mnames)

# %%
movies.head()
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
data = pd.merge(pd.merge(ratings, users), movies)

# %%
data.head()
# Out:
#    user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0        1      1193       5  978300760      F    1          10  48067
# 1        2      1193       5  978298413      M   56          16  70072
# 2       12      1193       4  978220179      M   25          12  32793
# 3       15      1193       4  978199279      M   25           7  22903
# 4       17      1193       5  978158471      M   50           1  95350
#
#                                     title genres
# 0  One Flew Over the Cuckoo's Nest (1975)  Drama
# 1  One Flew Over the Cuckoo's Nest (1975)  Drama
# 2  One Flew Over the Cuckoo's Nest (1975)  Drama
# 3  One Flew Over the Cuckoo's Nest (1975)  Drama
# 4  One Flew Over the Cuckoo's Nest (1975)  Drama

# %% [markdown]
# #ix[i] will select the row based on the i index

# %%
data.ix[0]
# Out:
# user_id                                            1
# movie_id                                        1193
# rating                                             5
# timestamp                                  978300760
# gender                                             F
# age                                                1
# occupation                                        10
# zip                                            48067
# title         One Flew Over the Cuckoo's Nest (1975)
# genres                                         Drama
# Name: 0, dtype: object

# %% [markdown]
# ### rows was changed to index and cols was changed to columns

# %%
mean_ratings = data.pivot_table('rating', index='title', columns='gender', aggfunc='mean')

# %%
mean_ratings[:5]
# Out:
# gender                                F         M
# title
# $1,000,000 Duck (1971)         3.375000  2.761905
# 'Night Mother (1986)           3.388889  3.352941
# 'Til There Was You (1997)      2.675676  2.733333
# 'burbs, The (1989)             2.793478  2.962085
# ...And Justice for All (1979)  3.828571  3.689024

# %%
type(mean_ratings)
# Out:
# pandas.core.frame.DataFrame

# %%
ratings_by_title = data.groupby('title').size()

# %%
ratings_by_title[:10]
# Out:
# title
# $1,000,000 Duck (1971)                37
# 'Night Mother (1986)                  70
# 'Til There Was You (1997)             52
# 'burbs, The (1989)                   303
# ...And Justice for All (1979)        199
# 1-900 (1994)                           2
# 10 Things I Hate About You (1999)    700
# 101 Dalmatians (1961)                565
# 101 Dalmatians (1996)                364
# 12 Angry Men (1957)                  616
# dtype: int64

# %%
ratings_by_title.head() ## no column header for the sum count -- different from R
# Out:
# title
# $1,000,000 Duck (1971)            37
# 'Night Mother (1986)              70
# 'Til There Was You (1997)         52
# 'burbs, The (1989)               303
# ...And Justice for All (1979)    199
# dtype: int64

# %%
active_titles = ratings_by_title.index[ratings_by_title >= 250]

# %%
active_titles
# Out:
# Index([u''burbs, The (1989)', u'10 Things I Hate About You (1999)',
#        u'101 Dalmatians (1961)', u'101 Dalmatians (1996)',
#        u'12 Angry Men (1957)', u'13th Warrior, The (1999)',
#        u'2 Days in the Valley (1996)', u'20,000 Leagues Under the Sea (1954)',
#        u'2001: A Space Odyssey (1968)', u'2010 (1984)',
#        ...
#        u'X-Men (2000)', u'Year of Living Dangerously (1982)',
#        u'Yellow Submarine (1968)', u'You've Got Mail (1998)',
#        u'Young Frankenstein (1974)', u'Young Guns (1988)',
#        u'Young Guns II (1990)', u'Young Sherlock Holmes (1985)',
#        u'Zero Effect (1998)', u'eXistenZ (1999)'],
#       dtype='object', name=u'title', length=1216)

# %%
type(active_titles)
# Out:
# pandas.core.index.Index

# %%
mean_ratings = mean_ratings.ix[active_titles]

# %%
mean_ratings.head()
# Out:
# gender                                    F         M
# title
# 'burbs, The (1989)                 2.793478  2.962085
# 10 Things I Hate About You (1999)  3.646552  3.311966
# 101 Dalmatians (1961)              3.791444  3.500000
# 101 Dalmatians (1996)              3.240000  2.911215
# 12 Angry Men (1957)                4.184397  4.328421

# %%
top_female_ratings = mean_ratings.sort_index(by='F', ascending=False)

# %%
top_female_ratings[:10]
# Out:
# gender                                                     F         M
# title
# Close Shave, A (1995)                               4.644444  4.473795
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)       4.572650  4.464589
# Wallace & Gromit: The Best of Aardman Animation...  4.563107  4.385075
# Schindler's List (1993)                             4.562602  4.491415
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Grand Day Out, A (1992)                             4.537879  4.293255
# To Kill a Mockingbird (1962)                        4.536667  4.372611
# Creature Comforts (1990)                            4.513889  4.272277
# Usual Suspects, The (1995)                          4.513317  4.518248

# %%
mean_ratings['diff'] = mean_ratings['M'] - mean_ratings['F']

# %%
sorted_by_diff = mean_ratings.sort_index(by='diff')

# %%
sorted_by_diff[:15]
# Out:
# gender                                        F         M      diff
# title
# Dirty Dancing (1987)                   3.790378  2.959596 -0.830782
# Jumpin' Jack Flash (1986)              3.254717  2.578358 -0.676359
# Grease (1978)                          3.975265  3.367041 -0.608224
# Little Women (1994)                    3.870588  3.321739 -0.548849
# Steel Magnolias (1989)                 3.901734  3.365957 -0.535777
# Anastasia (1997)                       3.800000  3.281609 -0.518391
# Rocky Horror Picture Show, The (1975)  3.673016  3.160131 -0.512885
# Color Purple, The (1985)               4.158192  3.659341 -0.498851
# Age of Innocence, The (1993)           3.827068  3.339506 -0.487561
# Free Willy (1993)                      2.921348  2.438776 -0.482573
# French Kiss (1995)                     3.535714  3.056962 -0.478752
# Little Shop of Horrors, The (1960)     3.650000  3.179688 -0.470312
# Guys and Dolls (1955)                  4.051724  3.583333 -0.468391
# Mary Poppins (1964)                    4.197740  3.730594 -0.467147
# Patch Adams (1998)                     3.473282  3.008746 -0.464536

# %%
sorted_by_diff[::-1][:15]
# Out:
# gender                                         F         M      diff
# title
# Good, The Bad and The Ugly, The (1966)  3.494949  4.221300  0.726351
# Kentucky Fried Movie, The (1977)        2.878788  3.555147  0.676359
# Dumb & Dumber (1994)                    2.697987  3.336595  0.638608
# Longest Day, The (1962)                 3.411765  4.031447  0.619682
# Cable Guy, The (1996)                   2.250000  2.863787  0.613787
# Evil Dead II (Dead By Dawn) (1987)      3.297297  3.909283  0.611985
# Hidden, The (1987)                      3.137931  3.745098  0.607167
# Rocky III (1982)                        2.361702  2.943503  0.581801
# Caddyshack (1980)                       3.396135  3.969737  0.573602
# For a Few Dollars More (1965)           3.409091  3.953795  0.544704
# Porky's (1981)                          2.296875  2.836364  0.539489
# Animal House (1978)                     3.628906  4.167192  0.538286
# Exorcist, The (1973)                    3.537634  4.067239  0.529605
# Fright Night (1985)                     2.973684  3.500000  0.526316
# Barb Wire (1996)                        1.585366  2.100386  0.515020

# %%
rating_std_by_title = data.groupby('title')['rating'].std()

# %%
rating_std_by_title.head()
# Out:
# title
# $1,000,000 Duck (1971)           1.092563
# 'Night Mother (1986)             1.118636
# 'Til There Was You (1997)        1.020159
# 'burbs, The (1989)               1.107760
# ...And Justice for All (1979)    0.878110
# Name: rating, dtype: float64

# %%
rating_std_by_title = rating_std_by_title.ix[active_titles]

# %%
rating_std_by_title.order(ascending=False)[:10]
# Out:
# title
# Dumb & Dumber (1994)                     1.321333
# Blair Witch Project, The (1999)          1.316368
# Natural Born Killers (1994)              1.307198
# Tank Girl (1995)                         1.277695
# Rocky Horror Picture Show, The (1975)    1.260177
# Eyes Wide Shut (1999)                    1.259624
# Evita (1996)                             1.253631
# Billy Madison (1995)                     1.249970
# Fear and Loathing in Las Vegas (1998)    1.246408
# Bicentennial Man (1999)                  1.245533
# Name: rating, dtype: float64

# %%
names1880 = pd.read_csv('ch02/names/yob1880.txt', names=['name', 'sex', 'births'])

# %%
names1880.head()
# Out:
#         name sex  births
# 0       Mary   F    7065
# 1       Anna   F    2604
# 2       Emma   F    2003
# 3  Elizabeth   F    1939
# 4     Minnie   F    1746

# %%
## first group by sex, then filter on births column, then sum
names1880.groupby('sex')['births'].sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %%
years = range(1880, 2011)

pieces = []
columns = ['name', 'sex', 'births']

for year in years:
    path = 'ch02/names/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)
    
    frame['year'] = year
    pieces.append(frame)
    
names = pd.concat(pieces, ignore_index=True)

# %%
names.head(20)
# Out:
#          name sex  births  year
# 0        Mary   F    7065  1880
# 1        Anna   F    2604  1880
# 2        Emma   F    2003  1880
# 3   Elizabeth   F    1939  1880
# 4      Minnie   F    1746  1880
# 5    Margaret   F    1578  1880
# 6         Ida   F    1472  1880
# 7       Alice   F    1414  1880
# 8      Bertha   F    1320  1880
# 9       Sarah   F    1288  1880
# 10      Annie   F    1258  1880
# 11      Clara   F    1226  1880
# 12       Ella   F    1156  1880
# 13   Florence   F    1063  1880
# 14       Cora   F    1045  1880
# 15     Martha   F    1040  1880
# 16      Laura   F    1012  1880
# 17     Nellie   F     995  1880
# 18      Grace   F     982  1880
# 19     Carrie   F     949  1880

# %%
total_births = names.pivot_table('births'
                                 , index='year'
                                 , columns = 'sex'
                                 , aggfunc=sum)
total_births.tail()
# Out:
# sex         F        M
# year
# 2006  1896468  2050234
# 2007  1916888  2069242
# 2008  1883645  2032310
# 2009  1827643  1973359
# 2010  1759010  1898382

# %%
total_births.plot(title='Total births by sex and year')
# Out:
# <img src="data:image/png;base64,...">

# %%
def add_prop(group):
    # Integer division floors
    births = group.births.astype(float)
    group['prop'] = births / births.sum()
    return group

# A prop value of 0.02 would indicate that 2 out 
# of every 100 babies was given a particular name
names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
# Remember that because births is of integer type, 
# we have to cast either the numerator or denominator to 
# floating point to compute a fraction
names.head()
# Out:
#         name sex  births  year      prop
# 0       Mary   F    7065  1880  0.077643
# 1       Anna   F    2604  1880  0.028618
# 2       Emma   F    2003  1880  0.022013
# 3  Elizabeth   F    1939  1880  0.021309
# 4     Minnie   F    1746  1880  0.019188

# %%
# do a quick sanity check and make sure everything sums to 1
# np.allclose = Returns True is two arrays are element-wise equal within a tolerance
np.allclose(names.groupby(['year', 'sex']).prop.sum(), 1)
# Out:
# True

# %%
def get_top1000(group):
    return group.sort_index(by='births', ascending=False)[:1000]
grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)
top1000.index = np.arange(len(top1000))
